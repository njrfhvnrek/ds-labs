# %%
# Лабораторная работа 1: Введение в Python и Git
# Автор: Растегаева Дарья ИНБб-4301 Исупов Андрей ИНБб-4301

# %%
def greet(name: str) -> str:
    """Возвращает приветствие для указанного имени."""
    return f"Привет, {name}!"

def compute_statistics(numbers):
    """Считает базовые статистики по списку чисел."""
    if not numbers:
      return None
    return {
      "count": len(numbers),
      "sum": sum(numbers),
      "min": min(numbers),
      "max": max(numbers),
      "avg": sum(numbers) / len(numbers),
    }

# %%
def factorial(n: int) -> int:
    """Рекурсивный факториал. n >= 0."""
    if n < 0:
        raise ValueError("factorial не определён для отрицательных чисел")
    return 1 if n <= 1 else n * factorial(n - 1)

# %%
print(f"5! = {factorial(5)}")
print(f"10! = {factorial(10)}")
# Out:
# 5! = 120
# 10! = 3628800

# %%
# 1. Приветствие
print(greet("Студент"))
# 2. Работа со списком
sample = [3, 1, 4, 1, 5, 9, 2, 6, 5, 3]
stats = compute_statistics(sample)
print(f"Список: {sample}")
for key, value in stats.items():
    print(f" {key:>5}: {value}")
# Out:
# Привет, Студент!
# Список: [3, 1, 4, 1, 5, 9, 2, 6, 5, 3]
#  count: 10
#    sum: 39
#    min: 1
#    max: 9
#    avg: 3.9
